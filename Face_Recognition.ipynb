# %% [markdown]
# <a href="https://colab.research.google.com/github/ashutosh1608/face_recognition/blob/main/Face_Recognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip '/content/drive/MyDrive/Face Recognition/Face Recog.zip'
# Out:
# Archive:  /content/drive/MyDrive/Face Recognition/Face Recog.zip
#    creating: Face Recog/Akshay Kumar/
#   inflating: Face Recog/Akshay Kumar/AK1.jpg
#   inflating: Face Recog/Akshay Kumar/AK10.jpeg
#   inflating: Face Recog/Akshay Kumar/AK11.jpg
#   inflating: Face Recog/Akshay Kumar/AK12.jpeg
#   inflating: Face Recog/Akshay Kumar/AK13.jpg
#   inflating: Face Recog/Akshay Kumar/AK14.jpg
#   inflating: Face Recog/Akshay Kumar/AK15.jpg
#   inflating: Face Recog/Akshay Kumar/AK16.jpg
#   inflating: Face Recog/Akshay Kumar/AK17.jpg
#   inflating: Face Recog/Akshay Kumar/AK18.jpg
#   inflating: Face Recog/Akshay Kumar/AK19.jpg
#   inflating: Face Recog/Akshay Kumar/AK2.jpeg
#   inflating: Face Recog/Akshay Kumar/AK20.jpg
#   inflating: Face Recog/Akshay Kumar/AK21.jpeg
#   inflating: Face Recog/Akshay Kumar/AK22.jpg
#   inflating: Face Recog/Akshay Kumar/AK23.jpg
#   inflating: Face Recog/Akshay Kumar/AK24.jpeg
#   inflating: Face Recog/Akshay Kumar/AK25.jpg
# ...

# %%
# !pip install mtcnn
# Out:
# ...
#      |████████████████████████████████| 2.3MB 12.5MB/s
# ...

# %%
# Import packages
import os
from PIL import Image
import helper


# Deine some params
SOURCE_BASE_PATH = "/content/Face Recog"
TARGET_BASE_PATH = "/content/Extracted Faces"


# Main
idx = 0
for cur_path in os.listdir(SOURCE_BASE_PATH):
    src_sub_path = os.path.join(SOURCE_BASE_PATH, cur_path)
    tgt_sub_path = os.path.join(TARGET_BASE_PATH, cur_path)
    
    if not os.path.isdir(tgt_sub_path):
        os.mkdir(tgt_sub_path)
    
    jdx = 0
    for filename in os.listdir(src_sub_path):
        print("Progress - idx: %s / %s" % (cur_path, filename))
        src_file_path = os.path.join(src_sub_path, filename)
        pixels = helper.extract_face(src_file_path)
        img = Image.fromarray(pixels, mode='RGB')
        img.save(os.path.join(tgt_sub_path, filename))
        
        jdx += 1
    
    idx += 1
# Out:
# Progress - idx: Salman Khan / SK7.jpg
# Progress - idx: Salman Khan / SK23.jpg
# WARNING:tensorflow:5 out of the last 47 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f3155738d90> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Progress - idx: Salman Khan / SK10.jpg
# ...

# %%
# Import libraries
import os
import cv2



# load the photo and extract the face
src_base_path = "/content/Extracted Faces"
tgt_base_path = "/content/Gray Scale Faces"


idx = 0
for cur_path in os.listdir(src_base_path):
    src_sub_path = os.path.join(src_base_path, cur_path)
    tgt_sub_path = os.path.join(tgt_base_path, cur_path)
    
    if not os.path.isdir(tgt_sub_path):
        os.mkdir(tgt_sub_path)
    
    jdx = 0
    for filename in os.listdir(src_sub_path):
        filepath = os.path.join(src_sub_path, filename)
        img = cv2.imread(filepath, cv2.IMREAD_GRAYSCALE)
        #img = Image.fromarray(img)
        #img.save(os.path.join(tgt_sub_path, filename))
        target_path = os.path.join(tgt_sub_path, filename)
        print(target_path)
        cv2.imwrite(target_path, img)
        jdx += 1
# Out:
# /content/Gray Scale Faces/Salman Khan/SK7.jpg
# /content/Gray Scale Faces/Salman Khan/SK23.jpg
# /content/Gray Scale Faces/Salman Khan/SK10.jpg
# /content/Gray Scale Faces/Salman Khan/SK18.jpg
# /content/Gray Scale Faces/Salman Khan/SK11.jpg
# /content/Gray Scale Faces/Salman Khan/SK6.jpg
# /content/Gray Scale Faces/Salman Khan/SK24.jpg
# /content/Gray Scale Faces/Salman Khan/SK5.jpg
# /content/Gray Scale Faces/Salman Khan/SK4.jpg
# /content/Gray Scale Faces/Salman Khan/SK9.jpg
# /content/Gray Scale Faces/Salman Khan/SK8.jpg
# /content/Gray Scale Faces/Salman Khan/SK21.jpg
# /content/Gray Scale Faces/Salman Khan/SK12.jpg
# /content/Gray Scale Faces/Salman Khan/SK20.jpg
# /content/Gray Scale Faces/Salman Khan/SK19.jpg
# /content/Gray Scale Faces/Salman Khan/SK17.jpg
# /content/Gray Scale Faces/Salman Khan/SK16.jpg
# /content/Gray Scale Faces/Salman Khan/SK1.jpg
# /content/Gray Scale Faces/Salman Khan/SK22.jpg
# /content/Gray Scale Faces/Salman Khan/SK3.jpeg
# ...

# %%
import os
import numpy as np

FACE_DATA_PATH = "/content/Gray Scale Faces"

NUMPY_DATA_PATH = '/content'
X_data_name = 'X_data.npy'
Y_data_name = 'Y_data.npy'

TOTAL_SAMPLE_SIZE = 20000
SIZE_TO_REDUCE = 2

X, Y = helper.get_data(FACE_DATA_PATH, SIZE_TO_REDUCE, TOTAL_SAMPLE_SIZE)

## save the data
if not os.path.exists(NUMPY_DATA_PATH):
  os.mkdir(NUMPY_DATA_PATH)

np.save(os.path.join(NUMPY_DATA_PATH, X_data_name), X)
np.save(os.path.join(NUMPY_DATA_PATH, Y_data_name), Y)
# Out:
# ......... NOW MAKING SIMILAR PAIRS .........
#
# [SIMILAR PAIRS] 500 / 20000
# [SIMILAR PAIRS] 1000 / 20000
# [SIMILAR PAIRS] 1500 / 20000
# [SIMILAR PAIRS] 2000 / 20000
# [SIMILAR PAIRS] 2500 / 20000
# [SIMILAR PAIRS] 3000 / 20000
# [SIMILAR PAIRS] 3500 / 20000
# [SIMILAR PAIRS] 4000 / 20000
# [SIMILAR PAIRS] 4500 / 20000
# [SIMILAR PAIRS] 5000 / 20000
# [SIMILAR PAIRS] 5500 / 20000
# [SIMILAR PAIRS] 6000 / 20000
# [SIMILAR PAIRS] 6500 / 20000
# [SIMILAR PAIRS] 7000 / 20000
# [SIMILAR PAIRS] 7500 / 20000
# [SIMILAR PAIRS] 8000 / 20000
# [SIMILAR PAIRS] 8500 / 20000
# [SIMILAR PAIRS] 9000 / 20000
# [SIMILAR PAIRS] 9500 / 20000
# [SIMILAR PAIRS] 10000 / 20000
# [SIMILAR PAIRS] 10500 / 20000
# [SIMILAR PAIRS] 11000 / 20000
# [SIMILAR PAIRS] 11500 / 20000
# [SIMILAR PAIRS] 12000 / 20000
# [SIMILAR PAIRS] 12500 / 20000
# [SIMILAR PAIRS] 13000 / 20000
# [SIMILAR PAIRS] 13500 / 20000
# [SIMILAR PAIRS] 14000 / 20000
# [SIMILAR PAIRS] 14500 / 20000
# [SIMILAR PAIRS] 15000 / 20000
# ...

# %%
# Import libraries
import os
import numpy as np

from sklearn.model_selection import train_test_split
from keras.layers import Input, Lambda
from keras.models import Model
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping, ModelCheckpoint
import siamese_network as SN

import matplotlib.pyplot as plt

# %%
# Define some params
DATA_PATH = '/content'
X_data_name = 'X_data.npy'
Y_data_name = 'Y_data.npy'

CHKPT_PATH = '/content'
CHK_PT_NAME = 'chkpt-model.ckpt'

MODEL_PATH = '/content/drive/MyDrive/Face Recognition'
MODEL_FILENAME = 'siamese-face-model.h5'

TEST_SIZE = .25
NUM_EPOCHS = 50
BATCH_SIZE = 128
PATIENCE = 10

# %%
# Main
X = np.load(os.path.join(DATA_PATH, X_data_name))
Y = np.load(os.path.join(DATA_PATH, Y_data_name))

print(X.shape)
print(Y.shape)
# Out:
# (40000, 2, 1, 80, 80)
# (40000, 1)

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=TEST_SIZE)

input_dim = x_train.shape[2:]
print(len(input_dim))
# Out:
# 3

# %%
img_a = Input(shape=input_dim)
img_b = Input(shape=input_dim)

base_network = SN.build_base_network(input_dim)
base_network.summary()

feat_vecs_a = base_network(img_a)
feat_vecs_b = base_network(img_b)

print(feat_vecs_a)
print(feat_vecs_b)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_1200 (Conv2D)         (None, 6, 78, 78)         60
# _________________________________________________________________
# activation (Activation)      (None, 6, 78, 78)         0
# _________________________________________________________________
# max_pooling2d_600 (MaxPoolin (None, 6, 39, 39)         0
# _________________________________________________________________
# dropout (Dropout)            (None, 6, 39, 39)         0
# _________________________________________________________________
# conv2d_1201 (Conv2D)         (None, 12, 37, 37)        660
# _________________________________________________________________
# activation_1 (Activation)    (None, 12, 37, 37)        0
# _________________________________________________________________
# max_pooling2d_601 (MaxPoolin (None, 12, 18, 18)        0
# ...

# %%
distance = Lambda(SN.euclidean_distance,
                  output_shape=SN.eucl_dist_output_shape)([feat_vecs_a, feat_vecs_b])

# %%
# Train
earlystopper = EarlyStopping(patience=PATIENCE, verbose=1)

if not os.path.exists(CHKPT_PATH):
  os.mkdir(CHKPT_PATH)
  
checkpt_path = os.path.join(CHKPT_PATH, CHK_PT_NAME)
print('Check Point File Path: %s' % (checkpt_path))

checkpointer = ModelCheckpoint(checkpt_path, verbose=1, save_best_only=True)

adam = Adam()
model = Model(inputs=[img_a, img_b], outputs=distance)
model.summary()

model.compile(loss=SN.contrastive_loss, optimizer=adam)

img_1 = x_train[:, 0]
img_2 = x_train[:, 1] 

# elapsed time checking
import time
start_time = time.time()

hist = model.fit([img_1, img_2],
                 y_train,
                 validation_split=TEST_SIZE,
                 batch_size=BATCH_SIZE,
                 verbose=2,
                 epochs=NUM_EPOCHS,
                 callbacks=[earlystopper, checkpointer])

print("\n\n Elapsed Time for Training: %s seconds ---" % (time.time() - start_time))
# Out:
# Check Point File Path: /content/chkpt-model.ckpt
# Model: "functional_601"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_301 (InputLayer)          [(None, 1, 80, 80)]  0
# __________________________________________________________________________________________________
# input_302 (InputLayer)          [(None, 1, 80, 80)]  0
# __________________________________________________________________________________________________
# sequential (Sequential)         (None, 50)           504962      input_301[0][0]
#                                                                  input_302[0][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 1)            0           sequential[0][0]
# ...

# %%
# Save the trained model
if not os.path.exists(MODEL_PATH):
  os.mkdir(MODEL_PATH)

model.save(os.path.join(MODEL_PATH, MODEL_FILENAME))

# %%
# Plot the Change in Loss over Epochs
for key in ['loss', 'val_loss']:
  plt.plot(hist.history[key], label=key)

plt.legend()
plt.show()

pred = model.predict([x_test[:, 0], x_test[:, 1]])

SN.compute_accuracy(pred, y_test)
# Out:
# 1.0

# %%
# !unzip '/content/Test Images.zip'
# Out:
# Archive:  /content/Test Images.zip
#    creating: Test Images/Akshay Kumar/
#   inflating: Test Images/Akshay Kumar/TAK1.jpg
#   inflating: Test Images/Akshay Kumar/TAK2.jpg
#   inflating: Test Images/Akshay Kumar/TAK3.jpg
#   inflating: Test Images/Akshay Kumar/TAK4.jpg
#   inflating: Test Images/Akshay Kumar/TAK5.jpg
#    creating: Test Images/Rajkummar Rao/
#   inflating: Test Images/Rajkummar Rao/TRR1.jpg
#   inflating: Test Images/Rajkummar Rao/TRR2.jpeg
#   inflating: Test Images/Rajkummar Rao/TRR3.jpg
#   inflating: Test Images/Rajkummar Rao/TRR4.jpg
#   inflating: Test Images/Rajkummar Rao/TRR5.jpg
#    creating: Test Images/Salman Khan/
#   inflating: Test Images/Salman Khan/TSK1.jpg
#   inflating: Test Images/Salman Khan/TSK2.jpg
#   inflating: Test Images/Salman Khan/TSK3.jpg
#   inflating: Test Images/Salman Khan/TSK4.jpg
#   inflating: Test Images/Salman Khan/TSK5.jpg
#    creating: Test Images/Sushant Singh Rajput/
# ...

# %%
from keras.models import load_model

# %%
DATA_PATH = "/content/Test Images"
MODEL_PATH = '/content/drive/MyDrive/Face Recognition'
MODEL_NAME = 'siamese-face-model.h5'
NUM_TRIALS = 500 ## Trials for Testing Accuracy

# %%
## load the model
model = load_model(os.path.join(MODEL_PATH, MODEL_NAME), custom_objects={'contrastive_loss': SN.contrastive_loss})

# %%
## test with many randomly selected images
matching = 0
for tiral in range(NUM_TRIALS):
    print("Now trial #%d of %d" % (tiral, NUM_TRIALS))

    pathlist = os.listdir(DATA_PATH)
    category = np.random.randint(len(pathlist))
    
    cur_path = os.path.join(DATA_PATH, pathlist[category])
    filelist = os.listdir(cur_path)
    index = np.random.randint(len(filelist))

    ref_image = helper.get_image(DATA_PATH, category, index)
    
    results = []
    for cat in range(len(pathlist)):
        filelist = os.listdir(os.path.join(DATA_PATH, pathlist[cat]))
        idx = np.random.randint(len(filelist))
        cur_image = helper.get_image(DATA_PATH, cat, idx)
        
        dist = model.predict([ref_image, cur_image])[0][0]
        results.append(dist)
    
    if category == np.argmin(results):
        matching += 1

print("Accuracy: %5.2f %%\n" % (100.0 * matching / NUM_TRIALS))

# %%
## select an image randomly (with only 1 image)
print("\n.... Now predict with the randomly selected image ....")
pathlist = os.listdir(DATA_PATH)
category = np.random.randint(len(pathlist))
cur_path = os.path.join(DATA_PATH, pathlist[category])
filelist = os.listdir(cur_path)
index = np.random.randint(len(filelist))

ref_image = helper.get_image(DATA_PATH, category, index)

results = []
for cat in range(len(pathlist)):
    filelist = os.listdir(os.path.join(DATA_PATH, pathlist[cat]))
    idx = np.random.randint(len(filelist))
    cur_image = helper.get_image(DATA_PATH, cat, idx)
    
    dist = model.predict([ref_image, cur_image])[0][0]
    results.append(dist)

print("Selected Category: %d" % (category))
print("Predicted Category: %d" % (np.argmin(results)))
